# %%
from PIL import Image
import random

# %%
data = Image.open("raster-fiveco_rgb_dem.png")

# %%
data.getpixel((5, 2))
# Out:
# 25

# %%
data.size
# Out:
# (2000, 2000)

# %%
Math.round((imgData.data[i]-image_factors[1])/image_factors[0]);

# %%
def valueFinder(value):
    value = (value * 256 + 1) + random.random()
    return value

# %%
random.random()
# Out:
# 0.8510186262844202

# %%
for row in range(50):
    for column in range(50):
        value = data.getpixel((row, column))
        elevation = valueFinder(value)
        groundTiles[row][column].elevation = elevation
